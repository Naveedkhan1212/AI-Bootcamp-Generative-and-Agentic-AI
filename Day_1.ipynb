# %% [markdown]
# Day 1 - Python Basics
# Variables, Print Statement, Comments, Data Types & Input

# %%
# ============================================
# Day 1 - Python Basics
# Author: Naveed Khan
# ============================================

print("Welcome to Python Programming!")
# Out:
# Welcome to Python Programming!

# %%
print("Hello World!")
print("Welcome to Python")
print("I am learning Python.")
print("Python is amazing!")
# Out:
# Hello World!
# Welcome to Python
# I am learning Python.
# Python is amazing!

# %% [markdown]
# Different Ways of Printing

# %%
print("Naveed")
print("Age:", 20)
print("Country:", "Pakistan")
print("AI Student")
# Out:
# Naveed
# Age: 20
# Country: Pakistan
# AI Student

# %% [markdown]
# Comments

# %%
# This is a single-line comment

"""
This is a
multi-line comment
"""

print("Comments do not affect program execution.")
# Out:
# Comments do not affect program execution.

# %% [markdown]
# Variables

# %%
name = "Naveed"
age = 20
city = "Peshawar"

print(name)
print(age)
print(city)
# Out:
# Naveed
# 20
# Peshawar

# %% [markdown]
# Rules for Variables

# %%
student_name = "Ali"
studentAge = 22
_marks = 95

print(student_name)
print(studentAge)
print(_marks)
# Out:
# Ali
# 22
# 95

# %% [markdown]
# Multiple Variables

# %%
a = 10
b = 20
c = 30

print(a)
print(b)
print(c)
# Out:
# 10
# 20
# 30

# %% [markdown]
# Assign Multiple Values

# %%
x, y, z = 100, 200, 300

print(x)
print(y)
print(z)
# Out:
# 100
# 200
# 300

# %% [markdown]
# - Same Value to Multiple Variables

# %%
a = b = c = 50

print(a)
print(b)
print(c)
# Out:
# 50
# 50
# 50

# %% [markdown]
# Data Types

# %%
name = "Naveed"
age = 20
height = 5.8
is_student = True

print(type(name))
print(type(age))
print(type(height))
print(type(is_student))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %% [markdown]
# String

# %%
message = "Hello Python"

print(message)
print(type(message))
# Out:
# Hello Python
# <class 'str'>

# %% [markdown]
# Integer

# %%
number = 100

print(number)
print(type(number))
# Out:
# 100
# <class 'int'>

# %% [markdown]
# Float

# %%
price = 999.99

print(price)
print(type(price))
# Out:
# 999.99
# <class 'float'>

# %% [markdown]
# Boolean

# %%
is_python_easy = True

print(is_python_easy)
print(type(is_python_easy))
# Out:
# True
# <class 'bool'>

# %% [markdown]
# Taking User Input

# %%
name = input("Enter your name: ")

print("Welcome", name)
# Out:
# Welcome naveed khan

# %% [markdown]
# Multiple Inputs

# %%
name = input("Enter Name: ")
age = input("Enter Age: ")
city = input("Enter City: ")

print(name)
print(age)
print(city)
# Out:
# naveed khan
# 20
# peshwar

# %% [markdown]
# Input and Data Type

# %%
age = int(input("Enter Age: "))

print(age)
print(type(age))
# Out:
# 20
# <class 'int'>

# %% [markdown]
# Simple Calculator

# %%
num1 = int(input("Enter First Number: "))
num2 = int(input("Enter Second Number: "))

sum = num1 + num2

print("Sum =", sum)
# Out:
# Sum = 30

# %% [markdown]
# Variable Swapping

# %%
a = 10
b = 20

print("Before Swapping")
print(a)
print(b)

a, b = b, a

print("After Swapping")
print(a)
print(b)
# Out:
# Before Swapping
# 10
# 20
# After Swapping
# 20
# 10

# %% [markdown]
# Mini Student Information Program

# %%
name = input("Enter Student Name: ")
age = int(input("Enter Age: "))
department = input("Enter Department: ")

print("\n----- Student Information -----")
print("Name:", name)
print("Age:", age)
print("Department:", department)
# Out:
# ----- Student Information -----
# Name: Naveed Khan
# Age: 20
# Department: AI

# %% [markdown]
# Mini Biodata Program

# %%
name = input("Name: ")
father = input("Father Name: ")
city = input("City: ")
phone = input("Phone Number: ")

print("\n========== BIO DATA ==========")
print("Name :", name)
print("Father :", father)
print("City :", city)
print("Phone :", phone)
# Out:
# ========== BIO DATA ==========
# Name : Naveed khan
# Father : Seva Jan
# City : Khyber
# Phone : 03161466031

# %% [markdown]
# Practice Program

# %%
company = "OpenAI"
course = "Python Programming"
duration = "3 Months"

print(company)
print(course)
print(duration)
# Out:
# OpenAI
# Python Programming
# 3 Months

# %% [markdown]
# Practice with Variables

# %%
first_name = "Naveed"
last_name = "Khan"

full_name = first_name + " " + last_name

print(full_name)
# Out:
# Naveed Khan

# %% [markdown]
# Mini Quiz

# %%
print("Python Quiz")

answer = input("Who developed Python? ")

print("Your Answer:", answer)
# Out:
# Python Quiz
# Your Answer: Guido Van Russom

# %% [markdown]
# Final Program

# %%
print("********************************")
print("      DAY 1 COMPLETED")
print("Python Basics Successfully Learned")
print("********************************")
# Out:
# ********************************
#       DAY 1 COMPLETED
# Python Basics Successfully Learned
# ********************************
