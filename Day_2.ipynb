# %% [markdown]
# Topics Covered
# ✅ Arithmetic Operators
# ✅ Assignment Operators
# ✅ Comparison Operators
# ✅ Logical Operators
# ✅ Identity Operators
# ✅ Membership Operators
# ✅ Bitwise Operators
# ✅ Calculator Program
# ✅ Percentage Calculator
# ✅ Area Calculations
# ✅ Temperature Converter
# ✅ Mini Shopping Bill
# ✅ Salary Calculator

# %%
# ============================================
# Day 2 - Python Operators
# Author: Naveed Khan
# ============================================

print("Welcome to Day 2 - Python Operators")
# Out:
# Welcome to Day 2 - Python Operators

# %% [markdown]
# Arithmetic Operators

# %%
a = 20
b = 5

print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)
print("Floor Division:", a // b)
print("Modulus:", a % b)
print("Exponent:", a ** b)
# Out:
# Addition: 25
# Subtraction: 15
# Multiplication: 100
# Division: 4.0
# Floor Division: 4
# Modulus: 0
# Exponent: 3200000

# %% [markdown]
# Arithmetic Practice

# %%
num1 = 15
num2 = 4

print(f"{num1} + {num2} =", num1 + num2)
print(f"{num1} - {num2} =", num1 - num2)
print(f"{num1} * {num2} =", num1 * num2)
print(f"{num1} / {num2} =", num1 / num2)
# Out:
# 15 + 4 = 19
# 15 - 4 = 11
# 15 * 4 = 60
# 15 / 4 = 3.75

# %% [markdown]
# Assignment Operators

# %%
x = 10

x += 5
print("After += :", x)

x -= 3
print("After -= :", x)

x *= 2
print("After *= :", x)

x /= 4
print("After /= :", x)
# Out:
# After += : 15
# After -= : 12
# After *= : 24
# After /= : 6.0

# %% [markdown]
# Comparison Operators

# %%
a = 20
b = 15

print(a == b)
print(a != b)
print(a > b)
print(a < b)
print(a >= b)
print(a <= b)
# Out:
# False
# True
# True
# False
# True
# False

# %% [markdown]
# Logical Operators

# %%
age = 20
has_id = True

print(age >= 18 and has_id)
print(age < 18 or has_id)
print(not has_id)
# Out:
# True
# True
# False

# %% [markdown]
# Identity Operators

# %%
a = [1, 2, 3]
b = a
c = [1, 2, 3]

print(a is b)
print(a is c)
print(a is not c)
# Out:
# True
# False
# True

# %% [markdown]
# Membership Operators

# %%
fruits = ["Apple", "Banana", "Orange"]

print("Apple" in fruits)
print("Mango" in fruits)
print("Mango" not in fruits)
# Out:
# True
# False
# True

# %% [markdown]
# Bitwise Operators

# %%
a = 5
b = 3

print("AND:", a & b)
print("OR:", a | b)
print("XOR:", a ^ b)
print("NOT:", ~a)
print("Left Shift:", a << 1)
print("Right Shift:", a >> 1)
# Out:
# AND: 1
# OR: 7
# XOR: 6
# NOT: -6
# Left Shift: 10
# Right Shift: 2

# %% [markdown]
# Calculator

# %%
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

print("Addition:", num1 + num2)
print("Subtraction:", num1 - num2)
print("Multiplication:", num1 * num2)
print("Division:", num1 / num2)
# Out:
# Addition: 30.0
# Subtraction: 10.0
# Multiplication: 200.0
# Division: 2.0

# %% [markdown]
# Even or Odd

# %%
number = int(input("Enter a number: "))

if number % 2 == 0:
    print("Even Number")
else:
    print("Odd Number")
# Out:
# Even Number

# %% [markdown]
# Largest Number

# %%
a = int(input("First Number: "))
b = int(input("Second Number: "))

if a > b:
    print(a, "is larger")
else:
    print(b, "is larger")
# Out:
# 20 is larger

# %% [markdown]
# Area of Rectangle

# %%
length = float(input("Length: "))
width = float(input("Width: "))

area = length * width

print("Area =", area)
# Out:
# Area = 20.0

# %% [markdown]
# Area of Circle

# %%
radius = float(input("Radius: "))

area = 3.14159 * radius ** 2

print("Area =", area)
# Out:
# Area = 50.26544

# %% [markdown]
# Celsius to Fahrenheit

# %%
celsius = float(input("Temperature in Celsius: "))

fahrenheit = (celsius * 9/5) + 32

print("Temperature in Fahrenheit:", fahrenheit)
# Out:
# Temperature in Fahrenheit: 104.0

# %% [markdown]
# Percentage Calculator

# %%
obtained = float(input("Obtained Marks: "))
total = float(input("Total Marks: "))

percentage = (obtained / total) * 100

print("Percentage =", percentage, "%")
# Out:
# Percentage = 90.0 %

# %% [markdown]
# Swap Numbers

# %%
a = int(input("First Number: "))
b = int(input("Second Number: "))

print("Before Swapping:", a, b)

a, b = b, a

print("After Swapping:", a, b)
# Out:
# Before Swapping: 20 10
# After Swapping: 10 20

# %% [markdown]
# Square and Cube

# %%
number = int(input("Enter a Number: "))

print("Square =", number ** 2)
print("Cube =", number ** 3)
# Out:
# Square = 900
# Cube = 27000

# %% [markdown]
# Mini Shopping Bill

# %%
item1 = float(input("Price of Item 1: "))
item2 = float(input("Price of Item 2: "))
item3 = float(input("Price of Item 3: "))

total = item1 + item2 + item3

print("Total Bill =", total)
# Out:
# Total Bill = 600.0

# %% [markdown]
# Mini Salary Calculator

# %%
basic = float(input("Basic Salary: "))

bonus = basic * 0.10
salary = basic + bonus

print("Bonus =", bonus)
print("Total Salary =", salary)
# Out:
# Bonus = 5000.0
# Total Salary = 55000.0

# %% [markdown]
# Practice Program

# %%
a = 12
b = 8

print(a + b)
print(a - b)
print(a * b)
print(a / b)
print(a > b)
print(a < b)
# Out:
# 20
# 4
# 96
# 1.5
# True
# False

# %% [markdown]
# print("=" * 40)
# print("🎉 Congratulations!")
# print("You have completed Day 2 of Python.")
# print("You learned all major Python operators.")
# print("=" * 40)
